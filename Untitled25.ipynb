# %% [markdown]
# <a href="https://colab.research.google.com/github/monahatami1/IntrotoAI/blob/master/Untitled25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

def draw_heart():
    # Define the heart shape
    t = np.linspace(0, 2*np.pi, 300)
    x = 19 * np.sin(t)**3
    y = 13 * np.cos(t) - 5 * np.cos(2*t) - 2 * np.cos(3*t) - np.cos(4*t)

    # Plot the heart shape
    fig, ax = plt.subplots(figsize=(6, 6))
    ax.plot(x, y, color='red')

    # Write the message inside the heart
    message = "Good Luck! From: Data RoadMap"
    ax.text(0, 1, message, fontsize=13, ha='center', va='center')

    # Set plot properties
    ax.axis('off')
    ax.set_aspect('equal')
    plt.show()

# Call the function to draw the heart and write the message
draw_heart()
